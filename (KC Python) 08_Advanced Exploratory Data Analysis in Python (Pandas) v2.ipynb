# %%
# Install the following modules
# !pip install pandas_datareader

# %%
# Install the openpyxl package to handle excel files properly
# !pip install openpyxl

# %%
import warnings
warnings.simplefilter("ignore")

# %%
# Clears all variable values previously set
from IPython import get_ipython
get_ipython().magic('reset -sf')

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd

# In Anaconda -> Environments -> Not Installed -> pandas-datareader -> Apply
from pandas_datareader import data as web # Reads stock data 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas provides numerous tools to work with tabular data like you'd find in spreadsheets or databases. It is widely used for data preparation, cleaning, and analysis. It can work with a wide variety of data and provides many visualization options. It is built on top of NumPy.

# %% [markdown]
# ## Read Data from a CSV

# %%
def get_df_from_csv(filename):
    try:
        df = pd.read_csv(filename, index_col='Date', parse_dates=True)
    except FileNotFoundError:
        pass
        print("File Does not Exist")
    else:
        print(f"The {filename} File was read successfully")
        return df

# %%
#ticker = "MSFT2"
#df = pd.read_csv(ticker + '.csv', index_col='Date', 
#                         parse_dates=True)

# %%
csv_file = 'MSFT.csv'
msft_df = get_df_from_csv(csv_file)
msft_df

# %%
## Pandas Dataframe attributes
msft_df_attributes = [x  for x in (dir(msft_df)) if x[0] != '_' ]
print(msft_df_attributes)

# %%
# Getting an idea of the structure of the dataframe
msft_df.info()

# %%
# int8 / uint8 : consumes 1 byte of memory, range between -128/127 or 0/255

# bool : consumes 1 byte, true or false

# float16 / int16 / uint16: consumes 2 bytes of memory, range between -32,768 and 32,767 or 0/65,535

# float32 / int32 / uint32 : consumes 4 bytes of memory, range between -2,147,483,648 and 2,147,483,647

# float64 / int64 / uint64: consumes 8 bytes of memory

# %%
# Getting all the available columns
msft_df.columns

# %%
# Summary of your dataframe
msft_df.describe()

# %%
# The float64 is too big, reduce it to float16, there are float16, float32, float64
# Changing all the columns with the object data type to string
number_columns = ['Adj Close', 'daily_return']
for column in number_columns:
    msft_df[column] = msft_df[column].astype ("float32")
    
msft_df.info()

# %%
msft_df.head(5) # Returns the first five rows

# %%
# Evaluating number of NaN values in our dataframe
msft_df.isna().sum()

# %%
# Removing the row containing the NaN values
msft_df = msft_df.dropna(axis=0) # Drop the rows containing NaN values, x=1 is for column
msft_df

# %%
# Getting a summary of the data
msft_df.describe()

# %% [markdown]
# ## Read Data from Excel

# %%
def get_df_from_excel(file):
    try:
        df = pd.read_excel(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        print(f"The {file} Excel File was read successfully")
        return df

# %%
# You may have to run this in the Qt Console : pip install openpyxl
file = "Wilshire-5000-Stocks.xlsx"
w_stocks = get_df_from_excel(file)
w_stocks

# %%
# Getting an idea of the structure of the dataframe
w_stocks.info()

# %%
# Getting all the available columns
w_stocks.columns

# %%
# Changing all the columns with the object data type to string
number_columns = ['Ticker', 'Company']
for column in number_columns:
    w_stocks[column] = w_stocks[column].astype ("string")
    
w_stocks.info()

# %%
# Getting a summary of the data
w_stocks.describe()

# %% [markdown]
# ## Read Data from HTML

# %%
gov_data = pd.read_html("https://en.wikipedia.org/wiki/List_of_current_United_States_governors")
gov_data

# %%
# We can define that we want the 2nd table on the page
gov_data = pd.read_html("https://en.wikipedia.org/wiki/List_of_current_United_States_governors")[1]
gov_data.head(5)

# %%
# Delete a level of a multilevel column name
gov_data.columns = gov_data.columns.droplevel()
gov_data.head(2)

# %%
gov_data.head(2)

# %%
#List all the available columns
gov_data.columns

# %%
# Delete all the columns containining only "NaN" and "List" Value
gov_data = gov_data.drop(['Image', 'Party', 'Unnamed: 9_level_1','Unnamed: 10_level_1'], axis=1)
gov_data.head(5)

# %% [markdown]
# ## Rename the "Party.1" column

# %%
# You could add additional with commas between {}
gov_data = gov_data.rename(columns={'Party.1': 'Party'})

gov_data.head(5)

# %%
gov_data[:5]

# %% [markdown]
# ## Remove Characters in Columns

# %%
# Remove parentheses and whats inside them
gov_data['End of term'] = gov_data['End of term'].str.replace(r"\(.*\)","", regex=True) 
# replaces any opening and closing bracket and everything inside with nothing("")
gov_data[:5]

# %%
# Extracting All the entire columns headers
print(list(gov_data.columns))

# %%
# Removing parentheses and whats inside them for all the Columns
df_headers = ['State', 'Governor', 'Party', 'Born', 'Prior public experience', 'Inauguration', 'End of term']

for header in df_headers:
    gov_data[header] = gov_data[header].str.replace(r"\(.*\)","", regex=True) 
# replaces any opening and closing bracket and everything inside with nothing("")
gov_data[:5]

# %%
# Remove parentheses and the age text inside the 'Born' column

# %%
gov_data[31:48:16]

# %%
# Remove square parentheses and whats inside them
gov_data['End of term'] = gov_data['End of term'].str.replace(r"\[.*\]","", regex=True) 
# replaces any opening and closing bracket and everything inside with nothing("")
gov_data[31:48:16]

# %%
# Removing square parentheses and whats inside them for all the Columns
df_headers = ['State', 'Governor', 'Party', 'Born', 'Prior public experience', 'Inauguration', 'End of term']

for header in df_headers:
    gov_data[header] = gov_data[header].str.replace(r"\[.*\]","", regex=True) 
# replaces any opening and closing bracket and everything inside with nothing("")

gov_data[31:48:16]

# %%
# "^–*.\w$

# %%
# Investigating the Party Column in line 22
gov_data[22:23]

# %%
# Remove the dash(-) symbol parentheses and what follows in line 22 and replace with nothing
gov_data ['Party'] = gov_data ['Party'].astype (str)
gov_data['Party'] = gov_data['Party'].str.replace(r"–Farmer–Labor","") 
# replaces any opening and closing bracket and everything inside with nothing("")
gov_data[22:23]

# %%
# Investigating the Governor Column in line 3 and 30
gov_data[3:31:27]

# %%
# Replacing the middle name  of the two Governors with initials
gov_data['Governor'] = gov_data['Governor'].str.replace(r"Sarah Huckabee Sanders","Sarah H. Sanders") 
gov_data['Governor'] = gov_data['Governor'].str.replace(r"Michelle Lujan Grisham","Michelle L. Grisham")
gov_data[3:31:27]

# %%
# Confirming the structure of our dataframe
gov_data.info()

# %%
# Confirming the number of columns
print(f"The number of columns are: {len(gov_data.columns)}")
gov_data.columns

# %%
# Changing all the columns with the object data type to string
number_columns = ['State', 'Governor', 'Party', 'Born', 'Prior public experience']
for column in number_columns:
    gov_data[column] = gov_data[column].astype ("string")
    
gov_data.info()

# %%
# Changing the columns with the object data type to date
date_columns = ['Born','Inauguration']
for column in date_columns:
    gov_data[column] = pd.to_datetime(gov_data[column],format="mixed")
    
gov_data.info()

# %%
number_columns = ['End of term']
for column in number_columns:
    gov_data[column] = gov_data[column].astype ('int16') # int16 ranges from -32,686 to 32,687
    
gov_data.info()

# %%
gov_data[0:5]

# %%
# Formatting  the datetime in the Born and Inauguration columns into Nigeria format
# Changing the columns with the object data type to date
date_columns = ['Born','Inauguration']
for column in date_columns:
    gov_data[column] = gov_data[column].dt.strftime('%d-%b-%Y') # e.g 10-Jan-2023

gov_data[0:5]

# %%
# Remove square parentheses and whats inside them
gov_data['State'] = gov_data['State'].str.replace(r"\(.*\)","", regex=True) 
# replaces any opening and closing bracket and everything inside with nothing("")
gov_data

# %%
# Remove square parentheses and whats inside them
gov_data['Born'] = gov_data['Born'].str.replace(r"\(.*\)","", regex=True) 
# replaces any opening and closing bracket and everything inside with nothing("")
gov_data

# %%
# Delete all the columns containining only "NaN" and "List" Value
gov_data = gov_data.drop(['Prior public experience'], axis=1)
gov_data.head(5)

# %%
# Confirming that the right data are in few columns

# %%
# Checking the State Column 
print(list(gov_data['State'].unique()))

# %%
# Checking the State Column 
print(list(gov_data['Party'].unique()))

# %%
gov_data['Party'] = gov_data['Party'].str.replace(r" ","") 
print(list(gov_data['Party'].unique()))

# %%
# Checking the State Column 
print(list(gov_data['End of term'].unique()))

# %%
# Checking Final Summary before Exporting
gov_data.head(5)

# %%
# Exporting our gov_data dataframe as CSV File
try:
    gov_data.to_excel("US_Governors_List_2023_v3.xlsx",index=False)
except:
    print("Error: Unable to convert dataframe to a excel file")
else:
    print("The Excel file successfully created.")

# %%
pwd

# %% [markdown]
# ## US Demographics

# %%
# You can also search for phrases in the table
d_data = pd.read_html("https://en.wikipedia.org/wiki/Demographics_of_the_United_States", 
                      match="Average population")
d_data

# %%
# You can also search for phrases in the table
d_data = pd.read_html("https://en.wikipedia.org/wiki/Demographics_of_the_United_States", 
                      match="Average population")[0]
d_data
# Out:
#         Unnamed: 0  Average population  Live births[92]   Deaths  \
# 0             1935           127250000          2377000  1392752
# 1             1936           128053000          2355000  1479228
# 2             1937           128825000          2413000  1450427
# 3             1938           129825000          2496000  1381391
# 4             1939           130880000          2466000  1387897
# ..             ...                 ...              ...      ...
# 83    2018[97][98]           326838199          3791712  2839205
# 84            2019           328329953          3747540  2854858
# 85   2020[99][100]           331501080          3613647  3383729
# 86  2021[101][102]           331893745          3664292  3464231
# 87  2022[103][104]           333287557          3667758  3273705
#
#     Natural change  Crude birth rate (per 1,000)  \
# 0           984248                          18.7
# 1           875772                          18.4
# 2           962573                          18.7
# 3          1114609                          19.2
# 4          1078103                          18.8
# ..             ...                           ...
# 83          952507                          11.6
# 84          892682                          11.4
# 85          229918                          10.9
# 86          200061                          11.0
# 87          394053                          11.0
#
#     Crude death rate (per 1,000)[93]  Natural change (per 1,000)  \
# 0                               10.9                         7.7
# 1                               11.5                         6.8
# 2                               11.2                         7.5
# 3                               10.6                         8.6
# 4                               10.6                         8.2
# ..                               ...                         ...
# 83                               8.7                         2.9
# 84                               8.7                         2.7
# 85                              10.3                         0.6
# 86                              10.4                         0.5
# 87                               9.8                         1.2
#
#     Crude migration change (per 1,000) Total fertility rate[fn 1][94]
# 0                                  NaN                           2.19
# 1                                 -0.5                           2.15
# 2                                 -1.5                           2.17
# 3                                 -0.9                           2.22
# 4                                 -0.1                           2.17
# ..                                 ...                            ...
# 83                                 2.4                          1.729
# 84                                 1.8                          1.706
# 85                                 8.9                          1.641
# 86                                 0.7                          1.664
# 87                                 3.0                     1.665[105]
#
# [88 rows x 10 columns]

# %% [markdown]
# ## Replace Spaces in Column Names

# %%
d_data.columns = [x.replace(' ', '_') for x in d_data.columns]
d_data
# Out:
#         Unnamed:_0  Average_population  Live_births[92]   Deaths  \
# 0             1935           127250000          2377000  1392752
# 1             1936           128053000          2355000  1479228
# 2             1937           128825000          2413000  1450427
# 3             1938           129825000          2496000  1381391
# 4             1939           130880000          2466000  1387897
# ..             ...                 ...              ...      ...
# 83    2018[97][98]           326838199          3791712  2839205
# 84            2019           328329953          3747540  2854858
# 85   2020[99][100]           331501080          3613647  3383729
# 86  2021[101][102]           331893745          3664292  3464231
# 87  2022[103][104]           333287557          3667758  3273705
#
#     Natural_change  Crude_birth_rate_(per_1,000)  \
# 0           984248                          18.7
# 1           875772                          18.4
# 2           962573                          18.7
# 3          1114609                          19.2
# 4          1078103                          18.8
# ..             ...                           ...
# 83          952507                          11.6
# 84          892682                          11.4
# 85          229918                          10.9
# 86          200061                          11.0
# 87          394053                          11.0
#
#     Crude_death_rate_(per_1,000)[93]  Natural_change_(per_1,000)  \
# 0                               10.9                         7.7
# 1                               11.5                         6.8
# 2                               11.2                         7.5
# 3                               10.6                         8.6
# 4                               10.6                         8.2
# ..                               ...                         ...
# 83                               8.7                         2.9
# 84                               8.7                         2.7
# 85                              10.3                         0.6
# 86                              10.4                         0.5
# 87                               9.8                         1.2
#
#     Crude_migration_change_(per_1,000) Total_fertility_rate[fn_1][94]
# 0                                  NaN                           2.19
# 1                                 -0.5                           2.15
# 2                                 -1.5                           2.17
# 3                                 -0.9                           2.22
# 4                                 -0.1                           2.17
# ..                                 ...                            ...
# 83                                 2.4                          1.729
# 84                                 1.8                          1.706
# 85                                 8.9                          1.641
# 86                                 0.7                          1.664
# 87                                 3.0                     1.665[105]
#
# [88 rows x 10 columns]

# %% [markdown]
# ## Remove Characters in Columns

# %%
# Remove parentheses and whats inside them
d_data.columns = d_data.columns.str.replace(r"\(.*\)","", regex=True) 
# replaces any opening and closing bracket and everything inside with nothing("")
d_data.head(5)
# Out:
#   Unnamed:_0  Average_population  Live_births[92]   Deaths  Natural_change  \
# 0       1935           127250000          2377000  1392752          984248
# 1       1936           128053000          2355000  1479228          875772
# 2       1937           128825000          2413000  1450427          962573
# 3       1938           129825000          2496000  1381391         1114609
# 4       1939           130880000          2466000  1387897         1078103
#
#    Crude_birth_rate_  Crude_death_rate_[93]  Natural_change_  \
# 0               18.7                   10.9              7.7
# 1               18.4                   11.5              6.8
# 2               18.7                   11.2              7.5
# 3               19.2                   10.6              8.6
# 4               18.8                   10.6              8.2
#
#    Crude_migration_change_ Total_fertility_rate[fn_1][94]
# 0                      NaN                           2.19
# 1                     -0.5                           2.15
# 2                     -1.5                           2.17
# 3                     -0.9                           2.22
# 4                     -0.1                           2.17

# %%
# Remove the square brackets and whatever is inside them
d_data.columns = d_data.columns.str.replace(r"\[.*\]","", regex=True)
# replaces any opening and closing square bracket and everything inside with nothing("")
d_data.head(5)
# Out:
#   Unnamed:_0  Average_population  Live_births   Deaths  Natural_change  \
# 0       1935           127250000      2377000  1392752          984248
# 1       1936           128053000      2355000  1479228          875772
# 2       1937           128825000      2413000  1450427          962573
# 3       1938           129825000      2496000  1381391         1114609
# 4       1939           130880000      2466000  1387897         1078103
#
#    Crude_birth_rate_  Crude_death_rate_  Natural_change_  \
# 0               18.7               10.9              7.7
# 1               18.4               11.5              6.8
# 2               18.7               11.2              7.5
# 3               19.2               10.6              8.6
# 4               18.8               10.6              8.2
#
#    Crude_migration_change_ Total_fertility_rate
# 0                      NaN                 2.19
# 1                     -0.5                 2.15
# 2                     -1.5                 2.17
# 3                     -0.9                 2.22
# 4                     -0.1                 2.17

# %% [markdown]
# ## Rename Columns

# %%
# You could add additional with commas between {}
d_data = d_data.rename(columns={'Unnamed:_0': 'Year'})

d_data
# Out:
#               Year  Average_population  Live_births   Deaths  Natural_change  \
# 0             1935           127250000      2377000  1392752          984248
# 1             1936           128053000      2355000  1479228          875772
# 2             1937           128825000      2413000  1450427          962573
# 3             1938           129825000      2496000  1381391         1114609
# 4             1939           130880000      2466000  1387897         1078103
# ..             ...                 ...          ...      ...             ...
# 83    2018[97][98]           326838199      3791712  2839205          952507
# 84            2019           328329953      3747540  2854858          892682
# 85   2020[99][100]           331501080      3613647  3383729          229918
# 86  2021[101][102]           331893745      3664292  3464231          200061
# 87  2022[103][104]           333287557      3667758  3273705          394053
#
#     Crude_birth_rate_  Crude_death_rate_  Natural_change_  \
# 0                18.7               10.9              7.7
# 1                18.4               11.5              6.8
# 2                18.7               11.2              7.5
# 3                19.2               10.6              8.6
# 4                18.8               10.6              8.2
# ..                ...                ...              ...
# 83               11.6                8.7              2.9
# 84               11.4                8.7              2.7
# 85               10.9               10.3              0.6
# 86               11.0               10.4              0.5
# 87               11.0                9.8              1.2
#
#     Crude_migration_change_ Total_fertility_rate
# 0                       NaN                 2.19
# 1                      -0.5                 2.15
# 2                      -1.5                 2.17
# 3                      -0.9                 2.22
# 4                      -0.1                 2.17
# ..                      ...                  ...
# 83                      2.4                1.729
# 84                      1.8                1.706
# 85                      8.9                1.641
# 86                      0.7                1.664
# 87                      3.0           1.665[105]
#
# [88 rows x 10 columns]

# %% [markdown]
# ## Remove any trailing underscores(_) from column names

# %%
d_data.columns = d_data.columns.str.replace(r"\_$","", regex=True) # ^_ for begining of column names with an _
# replaces any trailing underscores in the column names and replace with nothing("")
d_data
# Out:
#               Year  Average_population  Live_births   Deaths  Natural_change  \
# 0             1935           127250000      2377000  1392752          984248
# 1             1936           128053000      2355000  1479228          875772
# 2             1937           128825000      2413000  1450427          962573
# 3             1938           129825000      2496000  1381391         1114609
# 4             1939           130880000      2466000  1387897         1078103
# ..             ...                 ...          ...      ...             ...
# 83    2018[97][98]           326838199      3791712  2839205          952507
# 84            2019           328329953      3747540  2854858          892682
# 85   2020[99][100]           331501080      3613647  3383729          229918
# 86  2021[101][102]           331893745      3664292  3464231          200061
# 87  2022[103][104]           333287557      3667758  3273705          394053
#
#     Crude_birth_rate  Crude_death_rate  Natural_change  \
# 0               18.7              10.9             7.7
# 1               18.4              11.5             6.8
# 2               18.7              11.2             7.5
# 3               19.2              10.6             8.6
# 4               18.8              10.6             8.2
# ..               ...               ...             ...
# 83              11.6               8.7             2.9
# 84              11.4               8.7             2.7
# 85              10.9              10.3             0.6
# 86              11.0              10.4             0.5
# 87              11.0               9.8             1.2
#
#     Crude_migration_change Total_fertility_rate
# 0                      NaN                 2.19
# 1                     -0.5                 2.15
# 2                     -1.5                 2.17
# 3                     -0.9                 2.22
# 4                     -0.1                 2.17
# ..                     ...                  ...
# 83                     2.4                1.729
# 84                     1.8                1.706
# 85                     8.9                1.641
# 86                     0.7                1.664
# 87                     3.0           1.665[105]
#
# [88 rows x 10 columns]

# %%
d_data.columns
# Out:
# Index(['Year', 'Average_population', 'Live_births', 'Deaths', 'Natural_change',
#        'Crude_birth_rate', 'Crude_death_rate', 'Natural_change',
#        'Crude_migration_change', 'Total_fertility_rate'],
#       dtype='object')

# %%
tuple(d_data)
# Out:
# ('Year',
#  'Average_population',
#  'Live_births',
#  'Deaths',
#  'Natural_change',
#  'Crude_birth_rate',
#  'Crude_death_rate',
#  'Natural_change',
#  'Crude_migration_change',
#  'Total_fertility_rate')

# %%
# Checking the summary of the table
d_data.describe()
# Out:
#        Average_population   Live_births        Deaths  Natural_change  \
# count        8.800000e+01  8.800000e+01  8.800000e+01    8.800000e+01
# mean         2.256850e+08  3.696468e+06  2.029804e+06    1.667921e+06
# std          6.485722e+07  4.916846e+05  4.882452e+05    5.227649e+05
# min          1.272500e+08  2.355000e+06  1.381391e+06    2.000610e+05
# 25%          1.695365e+08  3.547217e+06  1.615965e+06    1.394533e+06
# 50%          2.233310e+08  3.820000e+06  1.968474e+06    1.644381e+06
# 75%          2.828640e+08  4.030857e+06  2.399049e+06    1.902447e+06
# max          3.332876e+08  4.316234e+06  3.464231e+06    2.666872e+06
#
#        Crude_birth_rate  Crude_death_rate  Natural_change  \
# count         88.000000         88.000000       88.000000
# mean          17.411364          9.167045        8.293182
# std            4.357935          0.827504        4.016855
# min           10.900000          7.900000        0.500000
# 25%           14.275000          8.575000        5.775000
# 50%           15.800000          8.850000        7.100000
# 75%           20.575000          9.600000       11.175000
# max           26.600000         11.500000       16.500000
#
#        Crude_migration_change
# count               87.000000
# mean                 2.679310
# std                  5.927981
# min                -22.600000
# 25%                  1.800000
# 50%                  3.000000
# 75%                  3.850000
# max                 41.000000

# %%
# Extracting the data information for the dataframe
d_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    88 non-null     object
#  1   Average_population      88 non-null     int64
#  2   Live_births             88 non-null     int64
#  3   Deaths                  88 non-null     int64
#  4   Natural_change          88 non-null     int64
#  5   Crude_birth_rate        88 non-null     float64
#  6   Crude_death_rate        88 non-null     float64
#  7   Natural_change          88 non-null     float64
#  8   Crude_migration_change  87 non-null     float64
#  9   Total_fertility_rate    88 non-null     object
# dtypes: float64(4), int64(4), object(2)
# memory usage: 7.0+ KB

# %%
# Selecting column headers for integers
int_data_columns = list(d_data.select_dtypes(include='int').columns) # number, float, bool, object, datetime
print(int_data_columns)
# Out:
# ['Average_population', 'Live_births', 'Deaths', 'Natural_change']

# %%
for column in int_data_columns:
    d_data[column] = d_data[column].astype ('int32') # int32 ranges from -2,147,483,648 to 2,147,483,647

d_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    88 non-null     object
#  1   Average_population      88 non-null     int32
#  2   Live_births             88 non-null     int32
#  3   Deaths                  88 non-null     int32
#  4   Natural_change          88 non-null     int32
#  5   Crude_birth_rate        88 non-null     float64
#  6   Crude_death_rate        88 non-null     float64
#  7   Natural_change          88 non-null     int32
#  8   Crude_migration_change  87 non-null     float64
#  9   Total_fertility_rate    88 non-null     object
# dtypes: float64(3), int32(5), object(2)
# memory usage: 5.3+ KB

# %%
# Selecting column headers for float
float_data_columns = list(d_data.select_dtypes(include='float').columns)
print(float_data_columns)
# Out:
# ['Crude_birth_rate', 'Crude_death_rate', 'Crude_migration_change']

# %%
for column in float_data_columns:
    d_data[column] = d_data[column].astype ('float16') #

d_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    88 non-null     object
#  1   Average_population      88 non-null     int32
#  2   Live_births             88 non-null     int32
#  3   Deaths                  88 non-null     int32
#  4   Natural_change          88 non-null     int32
#  5   Crude_birth_rate        88 non-null     float16
#  6   Crude_death_rate        88 non-null     float16
#  7   Natural_change          88 non-null     int32
#  8   Crude_migration_change  87 non-null     float16
#  9   Total_fertility_rate    88 non-null     object
# dtypes: float16(3), int32(5), object(2)
# memory usage: 3.7+ KB

# %%
# Selecting column headers for objects
object_data_columns = list(d_data.select_dtypes(include='object').columns)
print(object_data_columns)
# Out:
# ['Year', 'Total_fertility_rate']

# %%
#Investigating the unique values for year column
unique_years = d_data.Year.unique()
print(unique_years)
# Out:
# ['1935' '1936' '1937' '1938' '1939' '1940' '1941' '1942' '1943' '1944'
#  '1945' '1946' '1947' '1948' '1949' '1950' '1951' '1952' '1953' '1954'
#  '1955' '1956' '1957' '1958' '1959' '1960' '1961' '1962' '1963' '1964'
#  '1965' '1966' '1967' '1968' '1969' '1970' '1971' '1972' '1973' '1974'
#  '1975' '1976' '1977' '1978' '1979' '1980' '1981' '1982' '1983' '1984'
#  '1985' '1986' '1987' '1988' '1989' '1990' '1991' '1992' '1993' '1994'
#  '1995' '1996' '1997' '1998' '1999' '2000' '2001' '2002' '2003' '2004'
#  '2005' '2006' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014'
#  '2015' '2016' '2017[95][96]' '2018[97][98]' '2019' '2020[99][100]'
#  '2021[101][102]' '2022[103][104]']

# %%
# Cleaning up the square brackets and changing to the appropriate datatype
# Removing square parentheses and whats inside them for all the Columns
df_headers = ['Year']
for header in df_headers:
    d_data[header] = d_data[header].str.replace(r"\[.*\]","", regex=True)  # remove the square paretheses
    d_data[header] = d_data[header].astype("int16") # convert it data between -32,000 to +32,000

unique_years = d_data.Year.unique()
print(unique_years)
# Out:
# [1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947 1948
#  1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961 1962
#  1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976
#  1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990
#  1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004
#  2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018
#  2019 2020 2021 2022]

# %%
#Investigating the unique values for year column
unique_fertility_rate = d_data['Total_fertility_rate'].unique()
print(unique_fertility_rate)
# Out:
# ['2.19' '2.15' '2.17' '2.22' '2.301' '2.399' '2.628' '2.718' '2.568'
#  '2.491' '2.943' '3.274' '3.109' '3.110' '3.091' '3.269' '3.358' '3.424'
#  '3.543' '3.580' '3.689' '3.767' '3.701' '3.670' '3.654' '3.629' '3.474'
#  '3.333' '3.208' '2.928' '2.736' '2.578' '2.477' '2.465' '2.480' '2.266'
#  '2.010' '1.879' '1.835' '1.774' '1.738' '1.789' '1.760' '1.808' '1.839'
#  '1.812' '1.827' '1.799' '1.806' '1.844' '1.837' '1.872' '1.934' '2.014'
#  '2.081' '2.062' '2.046' '2.019' '2.001' '1.978' '1.976' '1.971' '1.999'
#  '2.007' '2.056' '2.030' '2.020' '2.047' '2.051' '2.057' '2.108' '2.120'
#  '2.072' '2.002' '1.931' '1.894' '1.880' '1.857' '1.862' '1.843' '1.820'
#  '1.765' '1.729' '1.706' '1.641' '1.664' '1.665[105]']

# %%
# Cleaning up the square brackets and changing to the appropriate datatype
# Removing square parentheses and whats inside them for all the Columns
df_headers = ['Total_fertility_rate']
for header in df_headers:
    d_data[header] = d_data[header].str.replace(r"\[.*\]","", regex=True)  # remove the square paretheses
    d_data[header] = d_data[header].astype("float16") # convert it data between -32,000 to +32,000

unique_fertility_rate = d_data['Total_fertility_rate'].unique()
print(unique_fertility_rate)
# Out:
# [2.19  2.15  2.17  2.22  2.3   2.398 2.629 2.719 2.568 2.49  2.943 3.273
#  3.11  3.092 3.27  3.357 3.424 3.543 3.58  3.69  3.768 3.701 3.67  3.654
#  3.629 3.475 3.332 3.207 2.928 2.736 2.578 2.477 2.465 2.48  2.266 2.01
#  1.879 1.835 1.774 1.738 1.789 1.76  1.808 1.839 1.812 1.827 1.799 1.806
#  1.844 1.837 1.872 1.934 2.014 2.08  2.062 2.047 2.02  2.002 1.978 1.976
#  1.971 1.999 2.008 2.057 2.03  2.05  2.107 2.12  2.072 1.931 1.894 1.88
#  1.857 1.862 1.843 1.82  1.765 1.729 1.706 1.641 1.664 1.665]

# %%
# Checking the summary again to establish the data are valid
d_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    88 non-null     int16
#  1   Average_population      88 non-null     int32
#  2   Live_births             88 non-null     int32
#  3   Deaths                  88 non-null     int32
#  4   Natural_change          88 non-null     int32
#  5   Crude_birth_rate        88 non-null     float16
#  6   Crude_death_rate        88 non-null     float16
#  7   Natural_change          88 non-null     int32
#  8   Crude_migration_change  87 non-null     float16
#  9   Total_fertility_rate    88 non-null     float16
# dtypes: float16(4), int16(1), int32(5)
# memory usage: 2.7 KB

# %%
# Evaluating the summary of the dataframe
d_data.describe()
# Out:
#               Year  Average_population   Live_births        Deaths  \
# count    88.000000        8.800000e+01  8.800000e+01  8.800000e+01
# mean   1978.500000        2.256850e+08  3.696468e+06  2.029804e+06
# std      25.547342        6.485722e+07  4.916846e+05  4.882452e+05
# min    1935.000000        1.272500e+08  2.355000e+06  1.381391e+06
# 25%    1956.750000        1.695365e+08  3.547217e+06  1.615965e+06
# 50%    1978.500000        2.233310e+08  3.820000e+06  1.968474e+06
# 75%    2000.250000        2.828640e+08  4.030857e+06  2.399049e+06
# max    2022.000000        3.332876e+08  4.316234e+06  3.464231e+06
#
#        Natural_change  Crude_birth_rate  Crude_death_rate  Natural_change  \
# count    8.800000e+01         88.000000         88.000000       88.000000
# mean     1.667921e+06         17.406250          9.164062        7.818182
# std      5.227649e+05          4.355469          0.827148        4.064269
# min      2.000610e+05         10.898438          7.898438        0.000000
# 25%      1.394533e+06         14.273438          8.576172        5.000000
# 50%      1.644381e+06         15.796875          8.847656        7.000000
# 75%      1.902447e+06         20.578125          9.601562       11.000000
# max      2.666872e+06         26.593750         11.500000       16.000000
#
#        Crude_migration_change  Total_fertility_rate
# count               87.000000             88.000000
# mean                 2.679688              2.339844
# std                  5.925781              0.629883
# min                -22.593750              1.640625
# 25%                  1.799805              1.861084
# 50%                  3.000000              2.053711
# 75%                  3.851562              2.651367
# max                 41.000000              3.767578

# %%
# Version 1 for single colums with no space in the column name
d_data.Live_births
# Out:
# 0     2377000
# 1     2355000
# 2     2413000
# 3     2496000
# 4     2466000
#        ...
# 83    3791712
# 84    3747540
# 85    3613647
# 86    3664292
# 87    3667758
# Name: Live_births, Length: 88, dtype: int32

# %%
# Version 2 for single colums with space or no space in the column name
d_data['Deaths']
# Out:
# 0     1392752
# 1     1479228
# 2     1450427
# 3     1381391
# 4     1387897
#        ...
# 83    2839205
# 84    2854858
# 85    3383729
# 86    3464231
# 87    3273705
# Name: Deaths, Length: 88, dtype: int32

# %% [markdown]
# ## Make a Column an Index

# %%
d_data.set_index('Year', inplace=True)
d_data
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 1935           127250000      2377000  1392752          984248
# 1936           128053000      2355000  1479228          875772
# 1937           128825000      2413000  1450427          962573
# 1938           129825000      2496000  1381391         1114609
# 1939           130880000      2466000  1387897         1078103
# ...                  ...          ...      ...             ...
# 2018           326838199      3791712  2839205          952507
# 2019           328329953      3747540  2854858          892682
# 2020           331501080      3613647  3383729          229918
# 2021           331893745      3664292  3464231          200061
# 2022           333287557      3667758  3273705          394053
#
#       Crude_birth_rate  Crude_death_rate  Natural_change  \
# Year
# 1935         18.703125         10.898438               7
# 1936         18.406250         11.500000               6
# 1937         18.703125         11.203125               7
# 1938         19.203125         10.601562               8
# 1939         18.796875         10.601562               8
# ...                ...               ...             ...
# 2018         11.601562          8.703125               2
# 2019         11.398438          8.703125               2
# 2020         10.898438         10.296875               0
# 2021         11.000000         10.398438               0
# 2022         11.000000          9.796875               1
#
#       Crude_migration_change  Total_fertility_rate
# Year
# 1935                     NaN              2.189453
# 1936               -0.500000              2.150391
# 1937               -1.500000              2.169922
# 1938               -0.899902              2.220703
# 1939               -0.099976              2.169922
# ...                      ...                   ...
# 2018                2.400391              1.728516
# 2019                1.799805              1.706055
# 2020                8.898438              1.640625
# 2021                0.700195              1.664062
# 2022                3.000000              1.665039
#
# [88 rows x 9 columns]

# %% [markdown]
# ## Grab Data from Multiple Columns

# %%
d_data[["Live_births", "Deaths"]] # Multiple columns must be in double square bracket
# Out:
#       Live_births   Deaths
# Year
# 1935      2377000  1392752
# 1936      2355000  1479228
# 1937      2413000  1450427
# 1938      2496000  1381391
# 1939      2466000  1387897
# ...           ...      ...
# 2018      3791712  2839205
# 2019      3747540  2854858
# 2020      3613647  3383729
# 2021      3664292  3464231
# 2022      3667758  3273705
#
# [88 rows x 2 columns]

# %% [markdown]
# ## Grab a Row

# %%
# Version 1
d_data.loc[2020]
# Out:
# Average_population        3.315011e+08
# Live_births               3.613647e+06
# Deaths                    3.383729e+06
# Natural_change            2.299180e+05
# Crude_birth_rate          1.089844e+01
# Crude_death_rate          1.029688e+01
# Natural_change            0.000000e+00
# Crude_migration_change    8.898438e+00
# Total_fertility_rate      1.640625e+00
# Name: 2020, dtype: float64

# %%
d_data.iloc[85] # row 86 is 2021 (the last), row 85 is 2020
# Out:
# Average_population        3.315011e+08
# Live_births               3.613647e+06
# Deaths                    3.383729e+06
# Natural_change            2.299180e+05
# Crude_birth_rate          1.089844e+01
# Crude_death_rate          1.029688e+01
# Natural_change            0.000000e+00
# Crude_migration_change    8.898438e+00
# Total_fertility_rate      1.640625e+00
# Name: 2020, dtype: float64

# %%
d_data[86:86] # Extracting the row horizontally
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 2020           331501080      3613647  3383729          229918
#
#       Crude_birth_rate  Crude_death_rate  Crude_migration_change  \
# Year
# 2020         10.898438         10.296875                8.898438
#
#       Total_fertility_rate  Pop_Growth
# Year
# 2020              1.640625      229918

# %%
d_data.tail(5)
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 2018           326838199      3791712  2839205          952507
# 2019           328329953      3747540  2854858          892682
# 2020           331501080      3613647  3383729          229918
# 2021           331893745      3664292  3464231          200061
# 2022           333287557      3667758  3273705          394053
#
#       Crude_birth_rate  Crude_death_rate  Natural_change  \
# Year
# 2018         11.601562          8.703125               2
# 2019         11.398438          8.703125               2
# 2020         10.898438         10.296875               0
# 2021         11.000000         10.398438               0
# 2022         11.000000          9.796875               1
#
#       Crude_migration_change  Total_fertility_rate
# Year
# 2018                2.400391              1.728516
# 2019                1.799805              1.706055
# 2020                8.898438              1.640625
# 2021                0.700195              1.664062
# 2022                3.000000              1.665039

# %%
d_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88 entries, 1935 to 2022
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Average_population      88 non-null     int32
#  1   Live_births             88 non-null     int32
#  2   Deaths                  88 non-null     int32
#  3   Natural_change          88 non-null     int32
#  4   Crude_birth_rate        88 non-null     float16
#  5   Crude_death_rate        88 non-null     float16
#  6   Natural_change          88 non-null     int32
#  7   Crude_migration_change  87 non-null     float16
#  8   Total_fertility_rate    88 non-null     float16
# dtypes: float16(4), int32(5)
# memory usage: 3.9 KB

# %%
d_data.columns
# Out:
# Index(['Average_population', 'Live_births', 'Deaths', 'Natural_change',
#        'Crude_birth_rate', 'Crude_death_rate', 'Natural_change',
#        'Crude_migration_change', 'Total_fertility_rate'],
#       dtype='object')

# %%
d_data.head(5)
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 1935           127250000      2377000  1392752          984248
# 1936           128053000      2355000  1479228          875772
# 1937           128825000      2413000  1450427          962573
# 1938           129825000      2496000  1381391         1114609
# 1939           130880000      2466000  1387897         1078103
#
#       Crude_birth_rate  Crude_death_rate  Natural_change  \
# Year
# 1935         18.703125         10.898438               7
# 1936         18.406250         11.500000               6
# 1937         18.703125         11.203125               7
# 1938         19.203125         10.601562               8
# 1939         18.796875         10.601562               8
#
#       Crude_migration_change  Total_fertility_rate
# Year
# 1935                     NaN              2.189453
# 1936               -0.500000              2.150391
# 1937               -1.500000              2.169922
# 1938               -0.899902              2.220703
# 1939               -0.099976              2.169922

# %%
# Keep only columns if they haven't used the same name prior.
# The code removes second columns with duplicated headings
d_data = d_data.loc[:,~d_data.columns.duplicated()] # ~ tilde
d_data.head(5)
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 1935           127250000      2377000  1392752          984248
# 1936           128053000      2355000  1479228          875772
# 1937           128825000      2413000  1450427          962573
# 1938           129825000      2496000  1381391         1114609
# 1939           130880000      2466000  1387897         1078103
#
#       Crude_birth_rate  Crude_death_rate  Crude_migration_change  \
# Year
# 1935         18.703125         10.898438                     NaN
# 1936         18.406250         11.500000               -0.500000
# 1937         18.703125         11.203125               -1.500000
# 1938         19.203125         10.601562               -0.899902
# 1939         18.796875         10.601562               -0.099976
#
#       Total_fertility_rate
# Year
# 1935              2.189453
# 1936              2.150391
# 1937              2.169922
# 1938              2.220703
# 1939              2.169922

# %%
# Specific columns can selected based on the column index from index 0 to the last index
d_data.iloc[0:,[0,2,7]]
# Out:
#       Average_population   Deaths  Total_fertility_rate
# Year
# 1936           128053000  1479228              2.150391
# 1937           128825000  1450427              2.169922
# 1938           129825000  1381391              2.220703
# 1939           130880000  1387897              2.169922
# 1940           131930000  1417269              2.300781
# ...                  ...      ...                   ...
# 2018           326838199  2839205              1.728516
# 2019           328329953  2854858              1.706055
# 2020           331501080  3383729              1.640625
# 2021           331893745  3464231              1.664062
# 2022           333287557  3273705              1.665039
#
# [87 rows x 3 columns]

# %%
d_data.head(5)
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 1935           127250000      2377000  1392752          984248
# 1936           128053000      2355000  1479228          875772
# 1937           128825000      2413000  1450427          962573
# 1938           129825000      2496000  1381391         1114609
# 1939           130880000      2466000  1387897         1078103
#
#       Crude_birth_rate  Crude_death_rate  Crude_migration_change  \
# Year
# 1935         18.703125         10.898438                     NaN
# 1936         18.406250         11.500000               -0.500000
# 1937         18.703125         11.203125               -1.500000
# 1938         19.203125         10.601562               -0.899902
# 1939         18.796875         10.601562               -0.099976
#
#       Total_fertility_rate
# Year
# 1935              2.189453
# 1936              2.150391
# 1937              2.169922
# 1938              2.220703
# 1939              2.169922

# %%
d_data.to_excel("For inspection.xlsx")
print("Dataframe converted to Excel file successfully..")
# Out:
# Dataframe converted to Excel file successfully..

# %%
# Create a column showing population growth for each year
d_data['Pop_Growth'] = d_data["Live_births"] - d_data["Deaths"]
d_data
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 1935           127250000      2377000  1392752          984248
# 1936           128053000      2355000  1479228          875772
# 1937           128825000      2413000  1450427          962573
# 1938           129825000      2496000  1381391         1114609
# 1939           130880000      2466000  1387897         1078103
# ...                  ...          ...      ...             ...
# 2018           326838199      3791712  2839205          952507
# 2019           328329953      3747540  2854858          892682
# 2020           331501080      3613647  3383729          229918
# 2021           331893745      3664292  3464231          200061
# 2022           333287557      3667758  3273705          394053
#
#       Crude_birth_rate  Crude_death_rate  Crude_migration_change  \
# Year
# 1935         18.703125         10.898438                     NaN
# 1936         18.406250         11.500000               -0.500000
# 1937         18.703125         11.203125               -1.500000
# 1938         19.203125         10.601562               -0.899902
# 1939         18.796875         10.601562               -0.099976
# ...                ...               ...                     ...
# 2018         11.601562          8.703125                2.400391
# 2019         11.398438          8.703125                1.799805
# 2020         10.898438         10.296875                8.898438
# 2021         11.000000         10.398438                0.700195
# 2022         11.000000          9.796875                3.000000
#
#       Total_fertility_rate  Pop_Growth
# Year
# 1935              2.189453      984248
# 1936              2.150391      875772
# 1937              2.169922      962573
# 1938              2.220703     1114609
# 1939              2.169922     1078103
# ...                    ...         ...
# 2018              1.728516      952507
# 2019              1.706055      892682
# 2020              1.640625      229918
# 2021              1.664062      200061
# 2022              1.665039      394053
#
# [88 rows x 9 columns]

# %% [markdown]
# ## Adding another Dummy Column

# %%
# Create a column showing population growth for each year
d_data['Dummy_column'] = d_data["Crude_death_rate"] - d_data["Deaths"]
d_data[:5]
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 1935           127250000      2377000  1392752          984248
# 1936           128053000      2355000  1479228          875772
# 1937           128825000      2413000  1450427          962573
# 1938           129825000      2496000  1381391         1114609
# 1939           130880000      2466000  1387897         1078103
#
#       Crude_birth_rate  Crude_death_rate  Crude_migration_change  \
# Year
# 1935         18.703125         10.898438                     NaN
# 1936         18.406250         11.500000               -0.500000
# 1937         18.703125         11.203125               -1.500000
# 1938         19.203125         10.601562               -0.899902
# 1939         18.796875         10.601562               -0.099976
#
#       Total_fertility_rate  Pop_Growth  Dummy_column
# Year
# 1935              2.189453      984248 -1.392741e+06
# 1936              2.150391      875772 -1.479216e+06
# 1937              2.169922      962573 -1.450416e+06
# 1938              2.220703     1114609 -1.381380e+06
# 1939              2.169922     1078103 -1.387886e+06

# %% [markdown]
# ## Delete Column

# %%
d_data.drop('Dummy_column', axis=1, inplace=True) # axis = 1 is for column, axis = 0 is for row
d_data
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 1935           127250000      2377000  1392752          984248
# 1936           128053000      2355000  1479228          875772
# 1937           128825000      2413000  1450427          962573
# 1938           129825000      2496000  1381391         1114609
# 1939           130880000      2466000  1387897         1078103
# ...                  ...          ...      ...             ...
# 2018           326838199      3791712  2839205          952507
# 2019           328329953      3747540  2854858          892682
# 2020           331501080      3613647  3383729          229918
# 2021           331893745      3664292  3464231          200061
# 2022           333287557      3667758  3273705          394053
#
#       Crude_birth_rate  Crude_death_rate  Crude_migration_change  \
# Year
# 1935         18.703125         10.898438                     NaN
# 1936         18.406250         11.500000               -0.500000
# 1937         18.703125         11.203125               -1.500000
# 1938         19.203125         10.601562               -0.899902
# 1939         18.796875         10.601562               -0.099976
# ...                ...               ...                     ...
# 2018         11.601562          8.703125                2.400391
# 2019         11.398438          8.703125                1.799805
# 2020         10.898438         10.296875                8.898438
# 2021         11.000000         10.398438                0.700195
# 2022         11.000000          9.796875                3.000000
#
#       Total_fertility_rate  Pop_Growth
# Year
# 1935              2.189453      984248
# 1936              2.150391      875772
# 1937              2.169922      962573
# 1938              2.220703     1114609
# 1939              2.169922     1078103
# ...                    ...         ...
# 2018              1.728516      952507
# 2019              1.706055      892682
# 2020              1.640625      229918
# 2021              1.664062      200061
# 2022              1.665039      394053
#
# [88 rows x 9 columns]

# %% [markdown]
# ## Delete a Row

# %%
d_data.drop(1935, axis=0, inplace=True) # x=0 is for row, x=1 is for column
d_data[:10]
# Out:
#       Average_population  Live_births   Deaths  Natural_change  \
# Year
# 1936           128053000      2355000  1479228          875772
# 1937           128825000      2413000  1450427          962573
# 1938           129825000      2496000  1381391         1114609
# 1939           130880000      2466000  1387897         1078103
# 1940           131930000      2559000  1417269         1142000
# 1941           133058000      2703000  1397642         1305358
# 1942           133752000      2989000  1385187         1603813
# 1943           133971000      3104000  1459544         1644306
# 1944           132622000      2939000  1411338         1644456
# 1945           132137000      2858000  1401719         1456281
#
#       Crude_birth_rate  Crude_death_rate  Crude_migration_change  \
# Year
# 1936         18.406250         11.500000               -0.500000
# 1937         18.703125         11.203125               -1.500000
# 1938         19.203125         10.601562               -0.899902
# 1939         18.796875         10.601562               -0.099976
# 1940         19.406250         10.796875               -0.700195
# 1941         20.296875         10.500000               -1.299805
# 1942         22.203125         10.296875               -6.800781
# 1943         22.796875         10.703125              -10.703125
# 1944         21.203125         10.203125              -22.593750
# 1945         20.406250         11.000000              -14.703125
#
#       Total_fertility_rate  Pop_Growth
# Year
# 1936              2.150391      875772
# 1937              2.169922      962573
# 1938              2.220703     1114609
# 1939              2.169922     1078103
# 1940              2.300781     1141731
# 1941              2.398438     1305358
# 1942              2.628906     1603813
# 1943              2.718750     1644456
# 1944              2.568359     1527662
# 1945              2.490234     1456281

# %% [markdown]
# ## List of Datatypes and value ranges

# %%
# int8 / uint8 : consumes 1 byte of memory, range between -128/127 or 0/255

# bool : consumes 1 byte, true or false

# float16 / int16 / uint16: consumes 2 bytes of memory, range between -32,768 and 32,767 or 0/65,535

# float32 / int32 / uint32 : consumes 4 bytes of memory, range between -2,147,483,648 and 2,147,483,647

# float64 / int64 / uint64: consumes 8 bytes of memory

# %%
# Confirming the number of columns
print(f"The number of columns are: {len(d_data.columns)}")
d_data.columns
# Out:
# The number of columns are: 9
# Index(['Average_population', 'Live_births', 'Deaths', 'Natural_change',
#        'Crude_birth_rate', 'Crude_death_rate', 'Crude_migration_change',
#        'Total_fertility_rate', 'Pop_Growth'],
#       dtype='object')

# %%
# Confirming that all data are the right format
    
d_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 1936 to 2022
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Average_population      87 non-null     int32
#  1   Live_births             87 non-null     int32
#  2   Deaths                  87 non-null     int32
#  3   Natural_change          87 non-null     int32
#  4   Crude_birth_rate        87 non-null     float16
#  5   Crude_death_rate        87 non-null     float16
#  6   Crude_migration_change  87 non-null     float16
#  7   Total_fertility_rate    87 non-null     float16
#  8   Pop_Growth              87 non-null     int32
# dtypes: float16(4), int32(5)
# memory usage: 2.5 KB

# %%
# Exporting our gov_data dataframe as MS Excel File
try:
    d_data.to_excel("US_Population_data.xlsx")
except:
    print("Error: Unable to convert dataframe to a csv file")
else:
    print("The Excel file successfully created.")
# Out:
# The Excel file successfully created.

# %% [markdown]
# ## Manipulating Data

# %%
c_data = pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)")[2]
c_data
# Out:
#     Country/Territory UN region IMF[1][13]            World Bank[14]  \
#     Country/Territory UN region   Forecast       Year       Estimate
# 0               World         —  104476432       2023      100562011
# 1       United States  Americas   26949643       2023       25462700
# 2               China      Asia   17700899  [n 1]2023       17963171
# 3             Germany    Europe    4429838       2023        4072192
# 4               Japan      Asia    4230862       2023        4231141
# ..                ...       ...        ...        ...            ...
# 209             Palau   Oceania        267       2023              —
# 210          Kiribati   Oceania        246       2023            223
# 211             Nauru   Oceania        150       2023            151
# 212        Montserrat  Americas          —          —              —
# 213            Tuvalu   Oceania         63       2023             60
#
#                United Nations[15]
#           Year           Estimate       Year
# 0         2022           96698005       2021
# 1         2022           23315081       2021
# 2    [n 3]2022           17734131  [n 1]2021
# 3         2022            4259935       2021
# 4         2022            4940878       2021
# ..         ...                ...        ...
# 209          —                218       2021
# 210       2022                227       2021
# 211       2022                155       2021
# 212          —                 72       2021
# 213       2022                 60       2021
#
# [214 rows x 8 columns]

# %%
for col in c_data.columns:
    print(col)
# Out:
# ('Country/Territory', 'Country/Territory')
# ('UN region', 'UN region')
# ('IMF[1][13]', 'Forecast')
# ('IMF[1][13]', 'Year')
# ('World Bank[14]', 'Estimate')
# ('World Bank[14]', 'Year')
# ('United Nations[15]', 'Estimate')
# ('United Nations[15]', 'Year')

# %%
# Delete a level of a multilevel column name
c_data.columns = c_data.columns.droplevel()
c_data
# Out:
#     Country/Territory UN region   Forecast       Year   Estimate       Year  \
# 0               World         —  104476432       2023  100562011       2022
# 1       United States  Americas   26949643       2023   25462700       2022
# 2               China      Asia   17700899  [n 1]2023   17963171  [n 3]2022
# 3             Germany    Europe    4429838       2023    4072192       2022
# 4               Japan      Asia    4230862       2023    4231141       2022
# ..                ...       ...        ...        ...        ...        ...
# 209             Palau   Oceania        267       2023          —          —
# 210          Kiribati   Oceania        246       2023        223       2022
# 211             Nauru   Oceania        150       2023        151       2022
# 212        Montserrat  Americas          —          —          —          —
# 213            Tuvalu   Oceania         63       2023         60       2022
#
#      Estimate       Year
# 0    96698005       2021
# 1    23315081       2021
# 2    17734131  [n 1]2021
# 3     4259935       2021
# 4     4940878       2021
# ..        ...        ...
# 209       218       2021
# 210       227       2021
# 211       155       2021
# 212        72       2021
# 213        60       2021
#
# [214 rows x 8 columns]

# %%
# Keep only columns if they haven't used the same name prior
# This codes removes "Estimate" column in column 7 and "Year" columns in column 6 and 8
c_data = c_data.loc[:,~c_data.columns.duplicated()]
c_data
# Out:
#     Country/Territory UN region   Forecast       Year   Estimate
# 0               World         —  104476432       2023  100562011
# 1       United States  Americas   26949643       2023   25462700
# 2               China      Asia   17700899  [n 1]2023   17963171
# 3             Germany    Europe    4429838       2023    4072192
# 4               Japan      Asia    4230862       2023    4231141
# ..                ...       ...        ...        ...        ...
# 209             Palau   Oceania        267       2023          —
# 210          Kiribati   Oceania        246       2023        223
# 211             Nauru   Oceania        150       2023        151
# 212        Montserrat  Americas          —          —          —
# 213            Tuvalu   Oceania         63       2023         60
#
# [214 rows x 5 columns]

# %%
# Counting how many rows with NaN values by taking only rows that don't contain NaNs
c_data.isna().sum()
# Out:
# Country/Territory    0
# UN region            0
# Forecast             0
# Year                 0
# Estimate             0
# dtype: int64

# %%
c_data[:5]
# Out:
#   Country/Territory UN region   Forecast       Year   Estimate
# 0             World         —  104476432       2023  100562011
# 1     United States  Americas   26949643       2023   25462700
# 2             China      Asia   17700899  [n 1]2023   17963171
# 3           Germany    Europe    4429838       2023    4072192
# 4             Japan      Asia    4230862       2023    4231141

# %%
# Checking that all the columns have valid data
c_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country/Territory  214 non-null    object
#  1   UN region          214 non-null    object
#  2   Forecast           214 non-null    object
#  3   Year               214 non-null    object
#  4   Estimate           214 non-null    object
# dtypes: object(5)
# memory usage: 8.5+ KB

# %%
#Investigating the unique values for year column
unique_years = c_data.Year.unique()
print(unique_years)
# Out:
# ['2023' '[n 1]2023' '[n 4]2023' '[n 5]2023' '[n 6]2023' '—' '[n 9]2023'
#  '[n 10]2023' '[n 11]2023' '[n 12]2021' '[n 14]2023']

# %%
# You can also investigating the unique values for year column using set data structure
unique_years_v2 = set(c_data.Year)
print(unique_years_v2)
# Out:
# {'[n 6]2023', '[n 10]2023', '[n 14]2023', '—', '[n 11]2023', '2023', '[n 1]2023', '[n 9]2023', '[n 4]2023', '[n 12]2021', '[n 5]2023'}

# %%
# Remove []s and what is in them in Year column
# Removes brackets and what is inside for whole column
c_data.Year = c_data.Year.str.replace(r"\[.*\]","", regex=True)
unique_years_v2 = set(c_data.Year)
print(unique_years_v2)
# Out:
# {'2021', '2023', '—'}
# C:\Users\Dr_Sam\AppData\Local\Temp\ipykernel_12484\2145597198.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data.Year = c_data.Year.str.replace(r"\[.*\]","", regex=True)

# %%
#Deleting rows in GDP column containing the special character (—)
c_data = c_data[~c_data.Year.str.contains("—", regex=False)]
unique_years_v2 = set(c_data.Year)
print(unique_years_v2)
# Out:
# {'2021', '2023'}

# %%
# Rename country column
c_data.rename(columns={"Country/Territory": "Country", "Estimate": "GDP"}, 
              inplace=True)
c_data
# Out:
# C:\Users\Dr_Sam\AppData\Local\Temp\ipykernel_12484\3543949302.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data.rename(columns={"Country/Territory": "Country", "Estimate": "GDP"},
#               Country UN region   Forecast  Year        GDP
# 0               World         —  104476432  2023  100562011
# 1       United States  Americas   26949643  2023   25462700
# 2               China      Asia   17700899  2023   17963171
# 3             Germany    Europe    4429838  2023    4072192
# 4               Japan      Asia    4230862  2023    4231141
# ..                ...       ...        ...   ...        ...
# 208  Marshall Islands   Oceania        277  2023        280
# 209             Palau   Oceania        267  2023          —
# 210          Kiribati   Oceania        246  2023        223
# 211             Nauru   Oceania        150  2023        151
# 213            Tuvalu   Oceania         63  2023         60
#
# [192 rows x 5 columns]

# %%
# You can also investigating the unique values for Country column using set data structure
unique_country_v2 = set(c_data.Country)
print(unique_country_v2)
# Out:
# {'Egypt', 'Indonesia', 'Turkey', 'Mozambique', 'Dominica', 'Cyprus', 'Greece', 'Switzerland', 'Kazakhstan', 'Moldova', 'Malta', 'Eswatini', 'Pakistan', 'Brunei', 'Gambia', 'Laos', 'Trinidad and Tobago', 'Aruba', 'Papua New Guinea', 'Australia', 'Dominican Republic', 'Belarus', 'Djibouti', 'Tanzania', 'South Sudan', 'Denmark', 'Uzbekistan', 'Latvia', 'Malawi', 'Saudi Arabia', 'Iceland', 'Hong Kong', 'Jordan', 'Honduras', 'Mongolia', 'Tunisia', 'Spain', 'Senegal', 'Comoros', 'Ecuador', 'South Korea', 'Kuwait', 'Mali', 'World', 'Panama', 'China', 'Puerto Rico', 'Ethiopia', 'Turkmenistan', 'Ireland', 'Kiribati', 'United Arab Emirates', 'Bahamas', 'Gabon', 'Paraguay', 'Slovakia', 'El Salvador', 'Bahrain', 'Micronesia', 'Iran', 'Saint Kitts and Nevis', 'Madagascar', 'Myanmar', 'San Marino', 'Zimbabwe', 'Nepal', 'Canada', 'Albania', 'Cape Verde', 'United States', 'Colombia', 'Slovenia', 'Bhutan', 'Iraq', 'Burkina Faso', 'Azerbaijan', 'Nauru', 'Suriname', 'Central African Republic', 'Kyrgyzstan', 'Oman', 'Vanuatu', 'Niger', 'Ukraine', 'Qatar', 'Kenya', 'Rwanda', 'Guyana', 'India', 'Angola', 'Uruguay', 'Philippines', 'Tonga', 'Singapore', 'Mauritania', 'Saint Lucia', 'Cambodia', 'United Kingdom', 'Hungary', 'Montenegro', 'East Timor', 'Germany', 'Liberia', 'Japan', 'Uganda', 'Guinea-Bissau', 'Andorra', 'Romania', 'Sierra Leone', 'North Macedonia', 'Georgia', 'Haiti', 'Algeria', 'Bulgaria', 'Costa Rica', 'Belize', 'Tuvalu', 'Venezuela', 'DR Congo', 'Croatia', 'Kosovo', 'South Africa', 'Portugal', 'Cameroon', 'Nigeria', 'Malaysia', 'São Tomé and Príncipe', 'Luxembourg', 'Togo', 'Morocco', 'Finland', 'Sweden', 'Yemen', 'Bolivia', 'Ghana', 'Nicaragua', 'Poland', 'Chile', 'Armenia', 'Austria', 'Somalia', 'Barbados', 'Solomon Islands', 'Maldives', 'Ivory Coast', 'Mauritius', 'Thailand', 'Macau', 'Israel', 'Burundi', 'Brazil', 'Norway', 'Mexico', 'Palau', 'France', 'Grenada', 'Netherlands', 'Chad', 'Libya', 'Jamaica', 'Argentina', 'Guatemala', 'Bosnia and Herzegovina', 'Sudan', 'Estonia', 'Seychelles', 'Bangladesh', 'Vietnam', 'Lesotho', 'Lithuania', 'Saint Vincent and the Grenadines', 'Antigua and Barbuda', 'Russia', 'Palestine', 'Marshall Islands', 'Taiwan', 'Tajikistan', 'Botswana', 'Italy', 'New Zealand', 'Peru', 'Samoa', 'Serbia', 'Belgium', 'Zambia', 'Equatorial Guinea', 'Guinea', 'Benin', 'Czech Republic', 'Namibia', 'Congo', 'Fiji'}

# %%
# Remove * in Country column
c_data.Country = c_data.Country.str.replace("*","",)
c_data
# Out:
# C:\Users\Dr_Sam\AppData\Local\Temp\ipykernel_12484\4091808008.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data.Country = c_data.Country.str.replace("*","")
#               Country UN region   Forecast  Year        GDP
# 0               World         —  104476432  2023  100562011
# 1       United States  Americas   26949643  2023   25462700
# 2               China      Asia   17700899  2023   17963171
# 3             Germany    Europe    4429838  2023    4072192
# 4               Japan      Asia    4230862  2023    4231141
# ..                ...       ...        ...   ...        ...
# 208  Marshall Islands   Oceania        277  2023        280
# 209             Palau   Oceania        267  2023          —
# 210          Kiribati   Oceania        246  2023        223
# 211             Nauru   Oceania        150  2023        151
# 213            Tuvalu   Oceania         63  2023         60
#
# [192 rows x 5 columns]

# %%
# Install the openpyxl package to handle excel files properly
# !pip install openpyxl

# %%
# You can also investigating the unique values for Country column using set data structure
unique_gdp_v2 = set(c_data.GDP)
print(unique_gdp_v2)
# Out:
# {'17098', '688177', '2824', '58066', '2383', '15672', '242632', '949', '113420', '578604', '40828', '12607', '75709', '10492', '1108149', '579267', '76523', '70334', '8126', '3073', '3163', '1675419', '632770', '495341', '13563', '43069', '17963171', '237296', '14616', '807706', '547', '343939', '14421', '905988', '20678', '13313', '6096', '3515', '24528', '301262', '6190', '151', '405870', '113435', '95003', '100562011', '106714', '4854', '78721', '984', '13970', '251945', '18885', '522033', '280826', '114667', '3385090', '41722', '191913', '1397509', '134182', '290924', '247234', '991115', '11814', '2315', '21072', '178789', '29957', '2065', '2553', '12897', '832', '46665', '47452', '44391', '477386', '20254', '21228', '219066', '4943', '460201', '1920096', '20352', '223', '1634', '10375', '1256', '2240422', '359839', '59364', '30633', '2139840', '466789', '17851', '12704', '13165', '51662', '160503', '24605', '82275', '220623', '585939', '60', '280', '301025', '476748', '2010432', '529245', '5638', '9429', '70965', '126783', '2782905', '264182', '62118', '15724', '962', '45559', '—', '29784', '16811', '612', '18882', '12898', '3352', '1758', '10931', '3070668', '376533', '27899', '72793', '44342', '406306', '19112', '16682', '3621', '38101', '32489', '17765', '21979', '18827', '395404', '45752', '388544', '70019', '4001', '25462700', '507535', '113642', '17402', '2273', '28439', '115049', '89040', '1243', '471400', '15358', '1414187', '3970', '68381', '71177', '408802', '41154', '27684', '31718', '115469', '4231141', '4072192', '1588', '1596', '80392', '1319100', '27842', '19503', '184558', '14955', '72839', '1665246', '427', '63502', '404284'}

# %%
#Deleting rows in GDP column containing the special character (—)
c_data = c_data[~c_data.GDP.str.contains("—", regex=False)]
c_data
# Out:
#               Country UN region   Forecast  Year        GDP
# 0               World         —  104476432  2023  100562011
# 1       United States  Americas   26949643  2023   25462700
# 2               China      Asia   17700899  2023   17963171
# 3             Germany    Europe    4429838  2023    4072192
# 4               Japan      Asia    4230862  2023    4231141
# ..                ...       ...        ...   ...        ...
# 205        Micronesia   Oceania        458  2023        427
# 208  Marshall Islands   Oceania        277  2023        280
# 210          Kiribati   Oceania        246  2023        223
# 211             Nauru   Oceania        150  2023        151
# 213            Tuvalu   Oceania         63  2023         60
#
# [182 rows x 5 columns]

# %%
# You can also investigating the unique values for Country column using set data structure
unique_un_region_v2 = set(c_data['UN region'])
print(unique_un_region_v2)
# Out:
# {'Europe', 'Africa', '—', 'Americas', 'Oceania', 'Asia'}

# %%
#Deleting rows in UN Region column containing the special character (—)
c_data = c_data[~c_data['UN region'].str.contains("—", regex=False)]
c_data
# Out:
#               Country UN region  Forecast  Year       GDP
# 1       United States  Americas  26949643  2023  25462700
# 2               China      Asia  17700899  2023  17963171
# 3             Germany    Europe   4429838  2023   4072192
# 4               Japan      Asia   4230862  2023   4231141
# 5               India      Asia   3732224  2023   3385090
# ..                ...       ...       ...   ...       ...
# 205        Micronesia   Oceania       458  2023       427
# 208  Marshall Islands   Oceania       277  2023       280
# 210          Kiribati   Oceania       246  2023       223
# 211             Nauru   Oceania       150  2023       151
# 213            Tuvalu   Oceania        63  2023        60
#
# [181 rows x 5 columns]

# %%
unique_un_region_v2 = set(c_data['UN region'])
print(unique_un_region_v2)
# Out:
# {'Africa', 'Europe', 'Americas', 'Oceania', 'Asia'}

# %%
# Confirming the structure of our dataframe
c_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181 entries, 1 to 213
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    181 non-null    object
#  1   UN region  181 non-null    object
#  2   Forecast   181 non-null    object
#  3   Year       181 non-null    object
#  4   GDP        181 non-null    object
# dtypes: object(5)
# memory usage: 8.5+ KB

# %%
# Confirming the number of columns
print(f"The number of columns are: {len(c_data.columns)}")
c_data.columns

# %%
# Changing all the columns with the object data type to string
number_columns = ['Country', 'UN region']
for column in number_columns:
    c_data[column] = c_data[column].astype ("string")
    
number_columns = ['GDP', 'Year','Forecast']
for column in number_columns:
    c_data[column] = c_data[column].astype ("int32")
    
c_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181 entries, 1 to 213
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    181 non-null    string
#  1   UN region  181 non-null    string
#  2   Forecast   181 non-null    int32
#  3   Year       181 non-null    int32
#  4   GDP        181 non-null    int32
# dtypes: int32(3), string(2)
# memory usage: 6.4 KB
# C:\Users\Dr_Sam\AppData\Local\Temp\ipykernel_12484\3356897723.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data[column] = c_data[column].astype ("string")
# C:\Users\Dr_Sam\AppData\Local\Temp\ipykernel_12484\3356897723.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data[column] = c_data[column].astype ("int32")
# C:\Users\Dr_Sam\AppData\Local\Temp\ipykernel_12484\3356897723.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data[column] = c_data[column].astype ("int32")
# C:\Users\Dr_Sam\AppData\Local\Temp\ipykernel_12484\3356897723.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data[column] = c_data[column].astype ("int32")

# %%
# Groupby allows you to group rows based on a column and perform a function
# Mean GDP by region
c_data[["UN region","GDP"]].groupby("UN region").mean()
# Out:
#                      GDP
# UN region
# Africa      56500.192308
# Americas   982007.647059
# Asia       880241.761905
# Europe     578681.195122
# Oceania    163565.166667

# %%
# Groupby allows you to group rows based on a column and perform a function
# Mean GDP by region
c_data[["UN region","GDP"]].groupby("UN region").sum()
# Out:
#                 GDP
# UN region
# Africa      2938010
# Americas   33388260
# Asia       36970154
# Europe     23725929
# Oceania     1962782

# %%
# Median GDP by region
c_data[["UN region","GDP"]].groupby("UN region").median()
# Out:
#                 GDP
# UN region
# Africa      17626.5
# Americas    37105.5
# Asia       202590.5
# Europe     178789.0
# Oceania       908.0

# %%
# Taking a final look at our c_data dataframe
c_data[:5]
# Out:
#          Country UN region  Forecast  Year       GDP
# 1  United States  Americas  26949643  2023  25462700
# 2          China      Asia  17700899  2023  17963171
# 3        Germany    Europe   4429838  2023   4072192
# 4          Japan      Asia   4230862  2023   4231141
# 5          India      Asia   3732224  2023   3385090

# %%
# Exporting our c_data dataframe as MS Excel File
filename = "Country_GDP.xlsx"
try:
    c_data.to_excel(filename)
except:
    print("Error: Unable to convert dataframe to a csv file")
else:
    print(f"The {filename} file successfully created.")
# Out:
# The Country_GDP.xlsx file successfully created.

# %% [markdown]
# ## Dealing with "HTTP Error 403: Forbidden" with Pandas

# %%
investment_data = pd.read_html("https://www.investing.com/earnings-calendar/")[1]
investment_data
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 investment_data = pd.read_html("https://www.investing.com/earnings-calendar/")[1]
#       2 investment_data
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
#    1231         is_file_like(io),
#    (...)
#    1235     ]
#    1236 ):
#    1237     warnings.warn(
#    1238         "Passing literal html to 'read_html' is deprecated and "
#    1239         "will be removed in a future version. To read from a "
#    (...)
#    1242         stacklevel=find_stack_level(),
#    1243     )
# -> 1245 return _parse(
#    1246     flavor=flavor,
#    1247     io=io,
#    1248     match=match,
#    1249     header=header,
#    1250     index_col=index_col,
#    1251     skiprows=skiprows,
#    1252     parse_dates=parse_dates,
#    1253     thousands=thousands,
#    1254     attrs=attrs,
#    1255     encoding=encoding,
#    1256     decimal=decimal,
#    1257     converters=converters,
#    1258     na_values=na_values,
#    1259     keep_default_na=keep_default_na,
#    1260     displayed_only=displayed_only,
#    1261     extract_links=extract_links,
#    1262     dtype_backend=dtype_backend,
#    1263     storage_options=storage_options,
#    1264 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\html.py:988, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     977 p = parser(
#     978     io,
#     979     compiled_match,
#    (...)
#     984     storage_options,
#     985 )
#     987 try:
# --> 988     tables = p.parse_tables()
#     989 except ValueError as caught:
#     990     # if `io` is an io-like object, check if it's seekable
#     991     # and try to rewind it before trying the next parser
#     992     if hasattr(io, "seekable") and io.seekable():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\html.py:248, in _HtmlFrameParser.parse_tables(self)
#     240 def parse_tables(self):
#     241     """
#     242     Parse and return all tables from the DOM.
#     243
#    (...)
#     246     list of parsed (header, body, footer) tuples from tables.
#     247     """
# --> 248     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     249     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\html.py:811, in _LxmlFrameParser._build_doc(self)
#     809             pass
#     810     else:
# --> 811         raise e
#     812 else:
#     813     if not hasattr(r, "text_content"):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\html.py:790, in _LxmlFrameParser._build_doc(self)
#     788 try:
#     789     if is_url(self.io):
# --> 790         with get_handle(
#     791             self.io, "r", storage_options=self.storage_options
#     792         ) as f:
#     793             r = parse(f.handle, parser=parser)
#     794     else:
#     795         # try to parse the input in the simplest way
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:372, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370 # assuming storage_options is to be interpreted as headers
#     371 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 372 with urlopen(req_info) as req:
#     373     content_encoding = req.headers.get("Content-Encoding", None)
#     374     if content_encoding == "gzip":
#     375         # Override compression based on Content-Encoding header
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:274, in urlopen(*args, **kwargs)
#     268 """
#     269 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     270 the stdlib.
#     271 """
#     272 import urllib.request
# --> 274 return urllib.request.urlopen(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
# !pip install html5lib

# %%
## Let's try to read a secure site
import requests
import pandas as pd
url_add = "https://www.investing.com/earnings-calendar/"
response = requests.get(url_add)

if response.status_code == 200:
    df = pd.read_html(response.content)[0]
    print(df.head())
else:
    print(f'Request failed: HTTP Error 403: Forbidden')
# Out:
#           Unnamed: 0_level_0                             Company  \
#           Unnamed: 0_level_1                             Company
# 0  Monday, November 27, 2023           Monday, November 27, 2023
# 1                        NaN  British American Tobacco ADR (BTI)
# 2                        NaN              Johnson Controls (JCI)
# 3                        NaN         Prudential Public ADR (PUK)
# 4                        NaN              Lonza Group AG (LZAGY)
#
#                          EPS                 / Forecast  \
#                          EPS                 / Forecast
# 0  Monday, November 27, 2023  Monday, November 27, 2023
# 1                         --                       / --
# 2                        1.1                     / 1.09
# 3                         --                       / --
# 4                         --                   / 0.9164
#
#                      Revenue                 / Forecast  \
#                      Revenue               / Forecast.1
# 0  Monday, November 27, 2023  Monday, November 27, 2023
# 1                         --                       / --
# 2                      7.11B                     / 7.1B
# 3                         --                       / --
# 4                         --                    / 3.24B
#
#                   Market Cap                       Time  \
#                   Market Cap                       Time
# 0  Monday, November 27, 2023  Monday, November 27, 2023
# 1                     71.85B                        NaN
# 2                     35.65B                        NaN
# 3                     31.85B                        NaN
# 4                     29.49B                        NaN
#
#           Unnamed: 8_level_0
#           Unnamed: 8_level_1
# 0  Monday, November 27, 2023
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
df
# Out:
#             Unnamed: 0_level_0                             Company  \
#             Unnamed: 0_level_1                             Company
# 0    Monday, November 27, 2023           Monday, November 27, 2023
# 1                          NaN  British American Tobacco ADR (BTI)
# 2                          NaN              Johnson Controls (JCI)
# 3                          NaN         Prudential Public ADR (PUK)
# 4                          NaN              Lonza Group AG (LZAGY)
# ..                         ...                                 ...
# 287                        NaN                       EnSync (ESNC)
# 288                        NaN                 Acura Pharma (ACUR)
# 289                        NaN        Great Panther Mining (GPLDF)
# 290                        NaN               Anthera Pharma (ANTH)
# 291                        NaN             Yuma Energy Inc (YUMAQ)
#
#                            EPS                 / Forecast  \
#                            EPS                 / Forecast
# 0    Monday, November 27, 2023  Monday, November 27, 2023
# 1                           --                       / --
# 2                          1.1                     / 1.09
# 3                           --                       / --
# 4                           --                   / 0.9164
# ..                         ...                        ...
# 287                         --                       / --
# 288                         --                       / --
# 289                         --                       / --
# 290                         --                       / --
# 291                         --                       / --
#
#                        Revenue                 / Forecast  \
#                        Revenue               / Forecast.1
# 0    Monday, November 27, 2023  Monday, November 27, 2023
# 1                           --                       / --
# 2                        7.11B                     / 7.1B
# 3                           --                       / --
# 4                           --                    / 3.24B
# ..                         ...                        ...
# 287                         --                       / --
# 288                         --                       / --
# 289                         --                       / --
# 290                         --                       / --
# 291                         --                       / --
#
#                     Market Cap                       Time  \
#                     Market Cap                       Time
# 0    Monday, November 27, 2023  Monday, November 27, 2023
# 1                       71.85B                        NaN
# 2                       35.65B                        NaN
# 3                       31.85B                        NaN
# 4                       29.49B                        NaN
# ..                         ...                        ...
# 287                         68                        NaN
# 288                         66                        NaN
# 289                         47                        NaN
# 290                         26                        NaN
# 291                          1                        NaN
#
#             Unnamed: 8_level_0
#             Unnamed: 8_level_1
# 0    Monday, November 27, 2023
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 287                        NaN
# 288                        NaN
# 289                        NaN
# 290                        NaN
# 291                        NaN
#
# [292 rows x 9 columns]

# %% [markdown]
# ### Solving "HTTP Error 403: Forbidden" with request module

# %%
import pandas as pd
import requests

url = 'https://tradingeconomics.com/currencies'
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

content = requests.get(url, headers=header)
secured_data = pd.read_html(content.text)
secured_data[0]
# Out:
# C:\Users\Dr_Sam\AppData\Local\Temp\ipykernel_12484\1340644819.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   secured_data = pd.read_html(content.text)
#     Unnamed: 0   Major       Price      Day       %  Weekly Monthly      YoY  \
# 0          NaN  EURUSD     1.09333  0.00290   0.27%   0.24%   3.51%    5.18%
# 1          NaN  GBPUSD     1.25939  0.00610   0.49%   1.07%   4.01%    4.14%
# 2          NaN  AUDUSD     0.65838  0.00268   0.41%   1.16%   4.37%   -2.45%
# 3          NaN  NZDUSD     0.60798  0.00330   0.54%   1.53%   4.79%   -2.63%
# 4          NaN  USDJPY   149.43200  0.12800  -0.09%  -0.13%  -0.52%    7.43%
# 5          NaN  USDCNY     7.14303  0.00580  -0.08%  -1.03%  -2.53%   -0.73%
# 6          NaN  USDCHF     0.88099  0.00320  -0.36%  -0.51%  -1.75%   -6.80%
# 7          NaN  USDCAD     1.36238  0.00680  -0.50%  -0.69%  -1.24%    1.85%
# 8          NaN  USDMXN    17.10080  0.07820  -0.46%  -0.61%  -6.60%  -11.53%
# 9          NaN  USDINR    83.34000  0.03500   0.04%   0.12%   0.24%    2.03%
# 10         NaN  USDBRL     4.90200  0.00190  -0.04%  -0.08%  -1.86%   -9.39%
# 11         NaN  USDRUB    89.29550  0.72500   0.82%  -0.48%  -5.00%   50.08%
# 12         NaN  USDKRW  1302.97000  2.77000   0.21%   0.67%  -3.66%   -2.36%
# 13         NaN  USDTRY    28.86360  0.08370   0.29%   0.73%   2.67%   55.31%
# 14         NaN     DXY   103.43200  0.33600  -0.32%  -0.47%  -2.91%   -2.39%
# 15         NaN  USDSEK    10.40750  0.06240  -0.60%  -0.87%  -6.63%   -0.04%
# 16         NaN  USDPLN     3.98070  0.02110  -0.53%  -0.80%  -5.92%  -11.63%
# 17         NaN  USDNOK    10.68354  0.07610  -0.71%  -1.04%  -4.49%    8.32%
# 18         NaN  USDZAR    18.77870  0.02120  -0.11%   2.23%  -1.75%    9.97%
# 19         NaN  USDDKK     6.80760  0.02830  -0.41%  -0.36%  -3.61%   -4.82%
# 20         NaN  USDSGD     1.33887  0.00150  -0.11%  -0.29%  -2.34%   -2.61%
# 21         NaN  USDILS     3.72350  0.01750  -0.47%   0.27%  -7.63%    8.86%
# 22         NaN  USDHKD     7.78883  0.00980  -0.13%  -0.08%  -0.42%   -0.31%
# 23         NaN  USDCLP   870.00000  3.38000  -0.39%  -1.69%  -5.70%   -5.49%
# 24         NaN  USDPKR   285.00000  5.00000   1.79%  -0.86%   1.89%   27.09%
# 25         NaN  USDCZK    22.21430  0.15770  -0.70%  -0.85%  -4.82%   -5.15%
# 26         NaN  USDHUF   346.30300  1.49700  -0.43%  -0.19%  -4.77%  -11.79%
#
#       Date
# 0   Nov/24
# 1   Nov/24
# 2   Nov/24
# 3   Nov/24
# 4   Nov/24
# 5   Nov/24
# 6   Nov/24
# 7   Nov/24
# 8   Nov/24
# 9   Nov/24
# 10  Nov/24
# 11  Nov/24
# 12  Nov/24
# 13  Nov/24
# 14  Nov/24
# 15  Nov/24
# 16  Nov/24
# 17  Nov/24
# 18  Nov/24
# 19  Nov/24
# 20  Nov/24
# 21  Nov/24
# 22  Nov/24
# 23  Nov/24
# 24  Nov/24
# 25  Nov/24
# 26  Nov/24

# %% [markdown]
# ### Pandas authorization by user and password

# %%
import requests
import pandas as pd

url = 'https://en-gb.facebook.com/login.php'
username = 'dr_sam@yahoo.com'
password = 'XXueyjdhhernf'

response = requests.get(url, auth=(username, password))

if response.status_code == 200:
    df = pd.read_html(response.content)[0]
    print(df.head())
else:
    print(f'Request failed')
